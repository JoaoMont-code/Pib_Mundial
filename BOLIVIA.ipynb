# %% [markdown]
# ## <font color='black'> PIB por cidade: BOLIVIA.</font>
# ## <font color='black'> Com pequenos dados fornecidos e procurados na internet conseguimos obter o PIB da bolivia por Cidade. </font>
# ## <font color='blue'> Feito por:João_Monteiro.</font>

# %%
#primeiro importamos os pacotes que iremos usar
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
#carregamos os dados
df = pd.read_csv('../../bases_de_dados/Boliviaa.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of   DEPARTAMENTO          1988          1989          1990          1991  \
# 0      BOLIVIA  1.421999e+07  1.475894e+07  1.544314e+07  1.625645e+07
# 1   CHUQUISACA  1.011577e+06  1.023186e+06  1.053112e+06  1.066240e+06
# 2       LA PAZ  3.927189e+06  4.059675e+06  4.166288e+06  4.454032e+06
# 3   COCHABAMBA  2.601747e+06  2.652732e+06  2.723101e+06  2.805674e+06
# 4        ORURO  7.453305e+05  8.033722e+05  8.457861e+05  9.063059e+05
# 5       POTOSÍ  8.423196e+05  8.783176e+05  9.297770e+05  9.779730e+05
# 6       TARIJA  7.074319e+05  7.431510e+05  8.072181e+05  8.597940e+05
# 7   SANTA CRUZ  3.674819e+06  3.871730e+06  4.144896e+06  4.421263e+06
# 8         BENI  6.060958e+05  6.199490e+05  6.524673e+05  6.458971e+05
# 9        PANDO  1.034783e+05  1.068292e+05  1.204909e+05  1.192752e+05
#
#            1992          1993          1994          1995          1996  ...  \
# 0  1.652411e+07  1.722958e+07  1.803373e+07  1.887740e+07  1.970070e+07  ...
# ...

# %%
#verificamos e analisamos os dados
df.head()
# Out:
#   DEPARTAMENTO          1988          1989          1990          1991  \
# 0      BOLIVIA  1.421999e+07  1.475894e+07  1.544314e+07  1.625645e+07
# 1   CHUQUISACA  1.011577e+06  1.023186e+06  1.053112e+06  1.066240e+06
# 2       LA PAZ  3.927189e+06  4.059675e+06  4.166288e+06  4.454032e+06
# 3   COCHABAMBA  2.601747e+06  2.652732e+06  2.723101e+06  2.805674e+06
# 4        ORURO  7.453305e+05  8.033722e+05  8.457861e+05  9.063059e+05
#
#            1992          1993          1994          1995          1996  ...  \
# 0  1.652411e+07  1.722958e+07  1.803373e+07  1.887740e+07  1.970070e+07  ...
# 1  1.048355e+06  1.069892e+06  1.047485e+06  1.047095e+06  1.037168e+06  ...
# 2  4.616862e+06  4.796133e+06  5.003282e+06  5.273419e+06  5.415494e+06  ...
# 3  2.853476e+06  2.998356e+06  3.191511e+06  3.410512e+06  3.580280e+06  ...
# 4  9.171285e+05  9.780166e+05  1.066423e+06  1.141119e+06  1.169103e+06  ...
#
#            2014          2015          2016       2017(p)       2018(p)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 37 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DEPARTAMENTO  10 non-null     object
#  1   info          10 non-null     float64
#  2   info          10 non-null     float64
#  3   1990          10 non-null     float64
#  4   1991          10 non-null     float64
#  5   1992          10 non-null     float64
#  6   1993          10 non-null     float64
#  7   1994          10 non-null     float64
#  8   1995          10 non-null     float64
#  9   1996          10 non-null     float64
#  10  1997          10 non-null     float64
#  11  1998          10 non-null     float64
#  12  1999          10 non-null     float64
#  13  2000          10 non-null     float64
#  14  2001          10 non-null     float64
#  15  2002          10 non-null     float64
#  16  2003          10 non-null     float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 37 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DEPARTAMENTO  10 non-null     object
#  1   info          10 non-null     float64
#  2   info          10 non-null     float64
#  3   1990          10 non-null     float64
#  4   1991          10 non-null     float64
#  5   1992          10 non-null     float64
#  6   1993          10 non-null     float64
#  7   1994          10 non-null     float64
#  8   1995          10 non-null     float64
#  9   1996          10 non-null     float64
#  10  1997          10 non-null     float64
#  11  1998          10 non-null     float64
#  12  1999          10 non-null     float64
#  13  2000          10 non-null     float64
#  14  2001          10 non-null     float64
#  15  2002          10 non-null     float64
#  16  2003          10 non-null     float64
# ...

# %%
#aqui importamos um grafico aonde fica claro a diferença do pib de cada cidade
plt.figure(figsize=(10, 7))
plt.hist(df_dsa['DEPARTAMENTO'], bins=20, edgecolor='yellow')
plt.xlabel('Cidades')
plt.ylabel('pib')
plt.title('Distribuição do PIB por cidade')
plt.grid(axis='y', alpha=0.75) 
plt.show()

# %%
df.corr
# Out:
# <bound method DataFrame.corr of   DEPARTAMENTO          info          info          1990          1991  \
# 0      BOLIVIA  1.421999e+07  1.475894e+07  1.544314e+07  1.625645e+07
# 1   CHUQUISACA  1.011577e+06  1.023186e+06  1.053112e+06  1.066240e+06
# 2       LA PAZ  3.927189e+06  4.059675e+06  4.166288e+06  4.454032e+06
# 3   COCHABAMBA  2.601747e+06  2.652732e+06  2.723101e+06  2.805674e+06
# 4        ORURO  7.453305e+05  8.033722e+05  8.457861e+05  9.063059e+05
# 5       POTOSÍ  8.423196e+05  8.783176e+05  9.297770e+05  9.779730e+05
# 6       TARIJA  7.074319e+05  7.431510e+05  8.072181e+05  8.597940e+05
# 7   SANTA CRUZ  3.674819e+06  3.871730e+06  4.144896e+06  4.421263e+06
# 8         BENI  6.060958e+05  6.199490e+05  6.524673e+05  6.458971e+05
# 9        PANDO  1.034783e+05  1.068292e+05  1.204909e+05  1.192752e+05
#
#            1992          1993          1994          1995          1996  ...  \
# ...

# %%
df.sum()
# Out:
# DEPARTAMENTO    BOLIVIACHUQUISACALA PAZCOCHABAMBAORUROPOTOSÍTA...
# info                                              28439973.699547
# info                                              29517885.614742
# 1990                                              30886273.603174
# 1991                                              32512906.118285
# 1992                                              33048229.669617
# 1993                                              34459157.268387
# 1994                                              36067456.611933
# 1995                                              37754793.238825
# 1996                                              39401409.053205
# 1997                                              41353436.132786
# 1998                                              43433246.870296
# 1999                                              43618656.255171
# 2000                                              44712530.613432
# ...

# %%
df.isnull()
# Out:
#    DEPARTAMENTO   info   info   1990   1991   1992   1993   1994   1995  \
# 0         False  False  False  False  False  False  False  False  False
# 1         False  False  False  False  False  False  False  False  False
# 2         False  False  False  False  False  False  False  False  False
# 3         False  False  False  False  False  False  False  False  False
# 4         False  False  False  False  False  False  False  False  False
# 5         False  False  False  False  False  False  False  False  False
# 6         False  False  False  False  False  False  False  False  False
# 7         False  False  False  False  False  False  False  False  False
# 8         False  False  False  False  False  False  False  False  False
# 9         False  False  False  False  False  False  False  False  False
#
#     1996  ...   2014   2015   2016  2017(p)  2018(p)  2019(p)  2020(p)  \
# 0  False  ...  False  False  False    False    False    False    False
# ...

# %% [markdown]
# ## <font color='black'>Podemos tirar como conclusão que o maior pib da bolivia pelas pequenas informações que possuimos é o da cidade de Santa Cruz</font>

# %% [markdown]
# ## <font color='blue'>Com aproximadamente: 11.376 milhões de dólares</font>
